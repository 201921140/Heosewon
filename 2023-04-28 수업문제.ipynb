# %% [markdown]
# ##eqtt,frs2,gee3,gh41,fb3g 의 키 값을 아래와 같이 나타내시오. (4줄로 작성)
# ['키값은 : eqtt 입니다.',
#  '키값은 : frs2 입니다.',
#  '키값은 : gee3 입니다.',
#  '키값은 : gh41 입니다.',
#  '키값은 : fb3g 입니다.']

# %%
# Out:
# ['키값은 : eqtt 입니다.',
#  '키값은 : frs2 입니다.',
#  '키값은 : gee3 입니다.',
#  '키값은 : gh41 입니다.',
#  '키값은 : fb3g 입니다.']

# %% [markdown]
# ##아래와 같은 결과를 만들어내시오(for문과 while문을 활용해서) 9줄 이하

# %%
# Out:
# ----1번째----
# 1번째 시도
# 2번째 시도
# 3번째 시도
# 4번째 시도
# 5번째 시도
# ----2번째----
# 1번째 시도
# 2번째 시도
# 3번째 시도
# 4번째 시도
# 5번째 시도
# ----3번째----
# 1번째 시도
# 2번째 시도
# 3번째 시도
# 4번째 시도
# 5번째 시도
# ----4번째----
# 1번째 시도
# 2번째 시도
# 3번째 시도
# 4번째 시도
# 5번째 시도
# ----5번째----
# 1번째 시도
# 2번째 시도
# 3번째 시도
# 4번째 시도
# 5번째 시도
# ----6번째----
# 1번째 시도
# 2번째 시도
# 3번째 시도
# 4번째 시도
# 5번째 시도
# ----7번째----
# 1번째 시도
# 2번째 시도
# 3번째 시도
# 4번째 시도
# 5번째 시도
